# %% [markdown]
# <a href="https://colab.research.google.com/github/ATHULTC/first-project/blob/main/Drug_Decision_Tree_Athul.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
import numpy as np

#Splitting the dataset into train and test
from sklearn.model_selection import train_test_split


#import the decisiontree classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report

# for pre-processing
from sklearn import preprocessing

# %%
#import the datasets
df = pd.read_csv("/content/drug200.csv")

# %%
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  drugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  drugY

# %%
df.dtypes
# Out:
# Age              int64
# Sex             object
# BP              object
# Cholesterol     object
# Na_to_K        float64
# Drug            object
# dtype: object

# %%
df.describe()
# Out:
#               Age     Na_to_K
# count  200.000000  200.000000
# mean    44.315000   16.084485
# std     16.544315    7.223956
# min     15.000000    6.269000
# 25%     31.000000   10.445500
# 50%     45.000000   13.936500
# 75%     58.000000   19.380000
# max     74.000000   38.247000

# %%
df.info
# Out:
# <bound method DataFrame.info of      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]>

# %%
df.shape
# Out:
# (200, 6)

# %%
df.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
label_encoder = preprocessing.LabelEncoder()
df['Sex'] = label_encoder.fit_transform(df['Sex'])
df['BP'] = label_encoder.fit_transform(df['BP'])
df['Drug'] = label_encoder.fit_transform(df['Drug'])

# %%
df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 0     23    0   0            0   25.355     4
# 1     47    1   1            0   13.093     2
# 2     47    1   1            0   10.114     2
# 3     28    0   2            0    7.798     3
# 4     61    0   1            0   18.043     4
# ..   ...  ...  ..          ...      ...   ...
# 195   56    0   1            0   11.567     2
# 196   16    1   1            0   12.006     2
# 197   52    1   2            0    9.894     3
# 198   23    1   2            1   14.020     3
# 199   40    0   1            1   11.349     3
#
# [200 rows x 6 columns]

# %%
x = df.iloc[:,0:5]
y = df.iloc[:,5]

# %%
x
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K
# 0     23    0   0            0   25.355
# 1     47    1   1            0   13.093
# 2     47    1   1            0   10.114
# 3     28    0   2            0    7.798
# 4     61    0   1            0   18.043
# ..   ...  ...  ..          ...      ...
# 195   56    0   1            0   11.567
# 196   16    1   1            0   12.006
# 197   52    1   2            0    9.894
# 198   23    1   2            1   14.020
# 199   40    0   1            1   11.349
#
# [200 rows x 5 columns]

# %%
y
# Out:
# 0      4
# 1      2
# 2      2
# 3      3
# 4      4
#       ..
# 195    2
# 196    2
# 197    3
# 198    3
# 199    3
# Name: Drug, Length: 200, dtype: int64

# %%
# Splitting the dataset into train and test

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=44)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((160, 5), (40, 5), (160,), (40,))

# %%
x_test
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K
# 135   74    1   1            1   11.939
# 73    41    0   2            1   22.905
# 157   53    1   1            0   22.963
# 28    39    0   1            1   22.697
# 23    48    0   1            0   15.036
# 79    32    0   1            1   10.840
# 54    68    0   0            1   10.189
# 3     28    0   2            0    7.798
# 114   20    0   2            1    9.281
# 124   53    0   0            1   12.495
# 180   22    0   0            1   22.818
# 111   47    0   2            1    6.683
# 182   20    0   1            1   11.686
# 64    60    0   0            0   13.303
# 9     43    1   1            1   19.368
# 68    54    1   2            0   24.658
# 35    46    1   2            1    7.285
# 45    66    0   2            1    8.107
# 89    50    0   2            1   17.211
# 47    68    1   1            0   10.291
# 177   25    1   2            0   19.011
# 126   66    1   0            0   16.347
# 142   60    1   0            1    8.621
# 7     41    1   1            0   11.037
# 12    43    1   1            0   15.376
# 32    49    1   1            1   11.014
# 181   59    0   2            0   13.884
# 136   55    0   0            0   10.977
# 105   37    1   1            1    8.968
# 178   39    1   2            0   15.969
# 48    23    1   2            0   31.686
# 190   58    1   0            0   18.991
# 112   35    1   1            1    9.170
# 81    64    1   2            0    7.761
# 95    36    1   1            1   11.424
# 43    23    1   2            0   12.260
# 158   59    0   1            0   10.444
# 187   47    1   0            0   10.403
# 99    15    0   0            1   16.725
# 65    68    0   2            1   27.050

# %%
y_test
# Out:
# 135    3
# 73     4
# 157    4
# 28     4
# 23     4
# 79     3
# 54     1
# 3      3
# 114    3
# 124    1
# 180    4
# 111    3
# 182    3
# 64     1
# 9      4
# 68     4
# 35     3
# 45     3
# 89     4
# 47     2
# 177    4
# 126    4
# 142    1
# 7      2
# 12     4
# 32     3
# 181    3
# 136    1
# 105    3
# 178    4
# 48     4
# 190    4
# 112    3
# 81     3
# 95     3
# 43     3
# 158    2
# 187    0
# 99     4
# 65     4
# Name: Drug, dtype: int64

# %%
# Building Decision Tree Classifier using Entropy as a Criterion

# %%
model =  DecisionTreeClassifier(criterion='entropy',max_depth = 4)

model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
# PLot the decsion Tree

# %%
tree.plot_tree(model)
# Out:
# [Text(0.625, 0.9, 'x[4] <= 14.829\nentropy = 1.962\nsamples = 160\nvalue = [22, 11, 13, 39, 75]'),
#  Text(0.5, 0.7, 'x[2] <= 0.5\nentropy = 1.816\nsamples = 85\nvalue = [22, 11, 13, 39, 0]'),
#  Text(0.25, 0.5, 'x[0] <= 50.5\nentropy = 0.918\nsamples = 33\nvalue = [22, 11, 0, 0, 0]'),
#  Text(0.125, 0.3, 'entropy = 0.0\nsamples = 22\nvalue = [22, 0, 0, 0, 0]'),
#  Text(0.375, 0.3, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11, 0, 0, 0]'),
#  Text(0.75, 0.5, 'x[2] <= 1.5\nentropy = 0.811\nsamples = 52\nvalue = [0, 0, 13, 39, 0]'),
#  Text(0.625, 0.3, 'x[3] <= 0.5\nentropy = 0.995\nsamples = 24\nvalue = [0, 0, 13, 11, 0]'),
#  Text(0.5, 0.1, 'entropy = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0]'),
#  Text(0.75, 0.1, 'entropy = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11, 0]'),
#  Text(0.875, 0.3, 'entropy = 0.0\nsamples = 28\nvalue = [0, 0, 0, 28, 0]'),
#  Text(0.75, 0.7, 'entropy = 0.0\nsamples = 75\nvalue = [0, 0, 0, 0, 75]')]

# %%
fn = ['Age','Sex','BP','Cholesterol','Na_to_K']
cn = ['drugA','drugB','drugC','drugX','drugY']
fig,axes = plt.subplots(nrows=1, ncols=1, figsize=(2,2), dpi=400)
tree.plot_tree(model,feature_names=fn,class_names = cn, filled=True)
# Out:
# [Text(0.625, 0.9, 'Na_to_K <= 14.829\nentropy = 1.962\nsamples = 160\nvalue = [22, 11, 13, 39, 75]\nclass = drugY'),
#  Text(0.5, 0.7, 'BP <= 0.5\nentropy = 1.816\nsamples = 85\nvalue = [22, 11, 13, 39, 0]\nclass = drugX'),
#  Text(0.25, 0.5, 'Age <= 50.5\nentropy = 0.918\nsamples = 33\nvalue = [22, 11, 0, 0, 0]\nclass = drugA'),
#  Text(0.125, 0.3, 'entropy = 0.0\nsamples = 22\nvalue = [22, 0, 0, 0, 0]\nclass = drugA'),
#  Text(0.375, 0.3, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11, 0, 0, 0]\nclass = drugB'),
#  Text(0.75, 0.5, 'BP <= 1.5\nentropy = 0.811\nsamples = 52\nvalue = [0, 0, 13, 39, 0]\nclass = drugX'),
#  Text(0.625, 0.3, 'Cholesterol <= 0.5\nentropy = 0.995\nsamples = 24\nvalue = [0, 0, 13, 11, 0]\nclass = drugC'),
#  Text(0.5, 0.1, 'entropy = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0]\nclass = drugC'),
#  Text(0.75, 0.1, 'entropy = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11, 0]\nclass = drugX'),
#  Text(0.875, 0.3, 'entropy = 0.0\nsamples = 28\nvalue = [0, 0, 0, 28, 0]\nclass = drugX'),
#  Text(0.75, 0.7, 'entropy = 0.0\nsamples = 75\nvalue = [0, 0, 0, 0, 75]\nclass = drugY')]

# %%
preds = model.predict(x_test)

# %%
pd.Series(preds).value_counts()
# Out:
# 4    16
# 3    15
# 1     5
# 2     3
# 0     1
# dtype: int64

# %%
preds
# Out:
# array([3, 4, 4, 4, 4, 3, 1, 3, 3, 1, 4, 3, 3, 1, 4, 4, 3, 3, 4, 2, 4, 4,
#        1, 2, 4, 3, 3, 1, 3, 4, 4, 4, 3, 3, 3, 3, 2, 0, 4, 4])

# %%
y_test
# Out:
# 135    3
# 73     4
# 157    4
# 28     4
# 23     4
# 79     3
# 54     1
# 3      3
# 114    3
# 124    1
# 180    4
# 111    3
# 182    3
# 64     1
# 9      4
# 68     4
# 35     3
# 45     3
# 89     4
# 47     2
# 177    4
# 126    4
# 142    1
# 7      2
# 12     4
# 32     3
# 181    3
# 136    1
# 105    3
# 178    4
# 48     4
# 190    4
# 112    3
# 81     3
# 95     3
# 43     3
# 158    2
# 187    0
# 99     4
# 65     4
# Name: Drug, dtype: int64

# %%
# Crosstab : Way to understand the two way table between predicted vs actual

# %%
pd.crosstab(y_test,preds)
# Out:
# col_0  0  1  2   3   4
# Drug
# 0      1  0  0   0   0
# 1      0  5  0   0   0
# 2      0  0  3   0   0
# 3      0  0  0  15   0
# 4      0  0  0   0  16

# %%
# Accuracy of the above model

# %%
np.mean(preds==y_test)
# Out:
# 1.0

# %%
x_test['preds']=preds

# %%
x_test['y_test']=y_test

# %%
x_test
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  preds  y_test
# 135   74    1   1            1   11.939      3       3
# 73    41    0   2            1   22.905      4       4
# 157   53    1   1            0   22.963      4       4
# 28    39    0   1            1   22.697      4       4
# 23    48    0   1            0   15.036      4       4
# 79    32    0   1            1   10.840      3       3
# 54    68    0   0            1   10.189      1       1
# 3     28    0   2            0    7.798      3       3
# 114   20    0   2            1    9.281      3       3
# 124   53    0   0            1   12.495      1       1
# 180   22    0   0            1   22.818      4       4
# 111   47    0   2            1    6.683      3       3
# 182   20    0   1            1   11.686      3       3
# 64    60    0   0            0   13.303      1       1
# 9     43    1   1            1   19.368      4       4
# 68    54    1   2            0   24.658      4       4
# 35    46    1   2            1    7.285      3       3
# 45    66    0   2            1    8.107      3       3
# 89    50    0   2            1   17.211      4       4
# 47    68    1   1            0   10.291      2       2
# 177   25    1   2            0   19.011      4       4
# 126   66    1   0            0   16.347      4       4
# 142   60    1   0            1    8.621      1       1
# 7     41    1   1            0   11.037      2       2
# 12    43    1   1            0   15.376      4       4
# 32    49    1   1            1   11.014      3       3
# 181   59    0   2            0   13.884      3       3
# 136   55    0   0            0   10.977      1       1
# 105   37    1   1            1    8.968      3       3
# 178   39    1   2            0   15.969      4       4
# 48    23    1   2            0   31.686      4       4
# 190   58    1   0            0   18.991      4       4
# 112   35    1   1            1    9.170      3       3
# 81    64    1   2            0    7.761      3       3
# 95    36    1   1            1   11.424      3       3
# 43    23    1   2            0   12.260      3       3
# 158   59    0   1            0   10.444      2       2
# 187   47    1   0            0   10.403      0       0
# 99    15    0   0            1   16.725      4       4
# 65    68    0   2            1   27.050      4       4
