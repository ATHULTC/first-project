# %%
# importing the libraries

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.35.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)

# %%
# Create your first MLP in Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import pandas as pd

# %%
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)
# load Heart disease dataset
df = pd.read_csv("/content/Heart_Disease_Prediction.csv", delimiter=",")

# %%
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 0       109                0            2.4            2
# 1       160                0            1.6            2
# 2       141                0            0.3            1
# 3       105                1            0.2            2
# 4       121                1            0.2            1
# ..      ...              ...            ...          ...
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium Heart Disease
# 0                          3         3      Presence
# 1                          0         7       Absence
# 2                          0         7      Presence
# 3                          1         7       Absence
# 4                          1         3       Absence
# ..                       ...       ...           ...
# 265                        0         7       Absence
# 266                        0         7       Absence
# 267                        0         3       Absence
# 268                        0         6       Absence
# 269                        3         3      Presence
#
# [270 rows x 14 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Sex'].plot(kind='hist', bins=20, title='Sex')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Chest pain type'].plot(kind='hist', bins=20, title='Chest pain type')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['BP'].plot(kind='hist', bins=20, title='BP')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Heart Disease').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='Age', y='Sex', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='Sex', y='Chest pain type', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='Chest pain type', y='BP', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='BP', y='Cholesterol', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['Sex'].plot(kind='line', figsize=(8, 4), title='Sex')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['Chest pain type'].plot(kind='line', figsize=(8, 4), title='Chest pain type')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['BP'].plot(kind='line', figsize=(8, 4), title='BP')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['Heart Disease'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='Age', y='Heart Disease', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['Heart Disease'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='Sex', y='Heart Disease', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['Heart Disease'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='Chest pain type', y='Heart Disease', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['Heart Disease'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='BP', y='Heart Disease', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ## Performing EDA

# %%
df.dtypes
# Out:
# Age                          int64
# Sex                          int64
# Chest pain type              int64
# BP                           int64
# Cholesterol                  int64
# FBS over 120                 int64
# EKG results                  int64
# Max HR                       int64
# Exercise angina              int64
# ST depression              float64
# Slope of ST                  int64
# Number of vessels fluro      int64
# Thallium                     int64
# Heart Disease               object
# dtype: object

# %%
df.describe()
# Out:
#               Age         Sex  Chest pain type          BP  Cholesterol  \
# count  270.000000  270.000000       270.000000  270.000000   270.000000
# mean    54.433333    0.677778         3.174074  131.344444   249.659259
# std      9.109067    0.468195         0.950090   17.861608    51.686237
# min     29.000000    0.000000         1.000000   94.000000   126.000000
# 25%     48.000000    0.000000         3.000000  120.000000   213.000000
# 50%     55.000000    1.000000         3.000000  130.000000   245.000000
# 75%     61.000000    1.000000         4.000000  140.000000   280.000000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS over 120  EKG results      Max HR  Exercise angina  ST depression  \
# count    270.000000   270.000000  270.000000       270.000000      270.00000
# mean       0.148148     1.022222  149.677778         0.329630        1.05000
# std        0.355906     0.997891   23.165717         0.470952        1.14521
# min        0.000000     0.000000   71.000000         0.000000        0.00000
# 25%        0.000000     0.000000  133.000000         0.000000        0.00000
# 50%        0.000000     2.000000  153.500000         0.000000        0.80000
# 75%        0.000000     2.000000  166.000000         1.000000        1.60000
# max        1.000000     2.000000  202.000000         1.000000        6.20000
#
#        Slope of ST  Number of vessels fluro    Thallium
# count   270.000000               270.000000  270.000000
# mean      1.585185                 0.670370    4.696296
# std       0.614390                 0.943896    1.940659
# min       1.000000                 0.000000    3.000000
# 25%       1.000000                 0.000000    3.000000
# 50%       2.000000                 0.000000    3.000000
# 75%       2.000000                 1.000000    7.000000
# max       3.000000                 3.000000    7.000000

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 265    False
# 266    False
# 267    False
# 268    False
# 269    False
# Length: 270, dtype: bool

# %%
df.isnull().sum()
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %% [markdown]
# ## Replacing presence with 1 and Absence with 0

# %%
df['Heart Disease'] = df['Heart Disease'].replace('Presence', 1)
df['Heart Disease'] = df['Heart Disease'].replace('Absence', 0)

# %%
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 0       109                0            2.4            2
# 1       160                0            1.6            2
# 2       141                0            0.3            1
# 3       105                1            0.2            2
# 4       121                1            0.2            1
# ..      ...              ...            ...          ...
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium  Heart Disease
# 0                          3         3              1
# 1                          0         7              0
# 2                          0         7              1
# 3                          1         7              0
# 4                          1         3              0
# ..                       ...       ...            ...
# 265                        0         7              0
# 266                        0         7              0
# 267                        0         3              0
# 268                        0         6              0
# 269                        3         3              1
#
# [270 rows x 14 columns]

# %%
# split into input (X) and output (Y) variables
X = df.iloc[1:,:13]
Y = df.iloc[1:,13]

# %%
print(X.shape)
# Out:
# (269, 13)

# %%
print(Y.shape)
# Out:
# (269,)

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=13, activation='relu'))  # Modify input_dim to match the number of features
model.add(Dense(10, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model
history = model.fit(X, Y, validation_split=0.3, epochs=120, batch_size=8)
# Out:
# Epoch 1/120
# 24/24 [==============================] - 1s 11ms/step - loss: 28.6283 - accuracy: 0.5532 - val_loss: 13.8155 - val_accuracy: 0.5679
# Epoch 2/120
# 24/24 [==============================] - 0s 4ms/step - loss: 6.2807 - accuracy: 0.5053 - val_loss: 3.2442 - val_accuracy: 0.5309
# Epoch 3/120
# 24/24 [==============================] - 0s 3ms/step - loss: 2.7750 - accuracy: 0.5691 - val_loss: 1.9482 - val_accuracy: 0.6296
# Epoch 4/120
# 24/24 [==============================] - 0s 4ms/step - loss: 2.4233 - accuracy: 0.6170 - val_loss: 1.9136 - val_accuracy: 0.6296
# Epoch 5/120
# 24/24 [==============================] - 0s 4ms/step - loss: 2.3478 - accuracy: 0.5691 - val_loss: 1.8947 - val_accuracy: 0.6173
# Epoch 6/120
# 24/24 [==============================] - 0s 4ms/step - loss: 2.2619 - accuracy: 0.5851 - val_loss: 1.8816 - val_accuracy: 0.5926
# Epoch 7/120
# 24/24 [==============================] - 0s 4ms/step - loss: 1.9353 - accuracy: 0.6064 - val_loss: 1.8473 - val_accuracy: 0.5802
# Epoch 8/120
# 24/24 [==============================] - 0s 4ms/step - loss: 1.7168 - accuracy: 0.6223 - val_loss: 1.4446 - val_accuracy: 0.6173
# Epoch 9/120
# 24/24 [==============================] - 0s 4ms/step - loss: 1.5913 - accuracy: 0.5957 - val_loss: 1.2104 - val_accuracy: 0.6667
# Epoch 10/120
# 24/24 [==============================] - 0s 4ms/step - loss: 1.3412 - accuracy: 0.6277 - val_loss: 1.0104 - val_accuracy: 0.6667
# Epoch 11/120
# 24/24 [==============================] - 0s 4ms/step - loss: 1.2156 - accuracy: 0.5904 - val_loss: 1.3696 - val_accuracy: 0.5926
# Epoch 12/120
# 24/24 [==============================] - 0s 4ms/step - loss: 1.1790 - accuracy: 0.5851 - val_loss: 0.7828 - val_accuracy: 0.6914
# Epoch 13/120
# 24/24 [==============================] - 0s 4ms/step - loss: 1.2117 - accuracy: 0.6277 - val_loss: 1.2441 - val_accuracy: 0.5802
# Epoch 14/120
# 24/24 [==============================] - 0s 4ms/step - loss: 1.1055 - accuracy: 0.6277 - val_loss: 0.6497 - val_accuracy: 0.6914
# Epoch 15/120
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8295 - accuracy: 0.6596 - val_loss: 0.8258 - val_accuracy: 0.6296
# Epoch 16/120
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8181 - accuracy: 0.6383 - val_loss: 0.5542 - val_accuracy: 0.7284
# Epoch 17/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.9314 - accuracy: 0.5851 - val_loss: 0.7401 - val_accuracy: 0.6420
# Epoch 18/120
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8666 - accuracy: 0.6064 - val_loss: 0.5475 - val_accuracy: 0.6914
# Epoch 19/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6595 - accuracy: 0.6968 - val_loss: 0.4943 - val_accuracy: 0.7778
# Epoch 20/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6446 - accuracy: 0.6862 - val_loss: 0.4831 - val_accuracy: 0.7407
# Epoch 21/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6256 - accuracy: 0.7021 - val_loss: 0.5026 - val_accuracy: 0.8148
# Epoch 22/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6277 - accuracy: 0.7074 - val_loss: 0.6531 - val_accuracy: 0.6420
# Epoch 23/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6141 - accuracy: 0.7021 - val_loss: 0.6023 - val_accuracy: 0.6790
# Epoch 24/120
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6975 - accuracy: 0.6649 - val_loss: 0.5906 - val_accuracy: 0.7037
# Epoch 25/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5952 - accuracy: 0.7340 - val_loss: 0.4584 - val_accuracy: 0.7901
# Epoch 26/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6030 - accuracy: 0.7394 - val_loss: 0.5029 - val_accuracy: 0.7407
# Epoch 27/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5481 - accuracy: 0.7553 - val_loss: 0.4401 - val_accuracy: 0.7778
# Epoch 28/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5502 - accuracy: 0.7447 - val_loss: 0.4342 - val_accuracy: 0.7778
# Epoch 29/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5870 - accuracy: 0.7447 - val_loss: 0.5364 - val_accuracy: 0.7531
# Epoch 30/120
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5618 - accuracy: 0.7606 - val_loss: 0.4650 - val_accuracy: 0.7407
# Epoch 31/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5541 - accuracy: 0.7181 - val_loss: 0.7202 - val_accuracy: 0.6667
# Epoch 32/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6615 - accuracy: 0.7021 - val_loss: 0.7660 - val_accuracy: 0.5926
# Epoch 33/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5247 - accuracy: 0.7447 - val_loss: 0.4296 - val_accuracy: 0.8148
# Epoch 34/120
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5392 - accuracy: 0.7553 - val_loss: 0.4659 - val_accuracy: 0.7407
# Epoch 35/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6277 - accuracy: 0.7128 - val_loss: 0.4611 - val_accuracy: 0.7407
# Epoch 36/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6442 - accuracy: 0.7234 - val_loss: 0.4819 - val_accuracy: 0.7531
# Epoch 37/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5458 - accuracy: 0.7500 - val_loss: 0.4080 - val_accuracy: 0.8148
# Epoch 38/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5318 - accuracy: 0.7553 - val_loss: 0.4114 - val_accuracy: 0.8025
# Epoch 39/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4978 - accuracy: 0.8085 - val_loss: 0.4532 - val_accuracy: 0.7531
# Epoch 40/120
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5056 - accuracy: 0.7606 - val_loss: 0.3900 - val_accuracy: 0.8272
# Epoch 41/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5266 - accuracy: 0.7606 - val_loss: 0.4152 - val_accuracy: 0.8025
# Epoch 42/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4765 - accuracy: 0.7872 - val_loss: 0.3936 - val_accuracy: 0.8519
# Epoch 43/120
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4825 - accuracy: 0.8085 - val_loss: 0.4124 - val_accuracy: 0.7778
# Epoch 44/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5370 - accuracy: 0.7713 - val_loss: 0.4475 - val_accuracy: 0.7778
# Epoch 45/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5050 - accuracy: 0.7553 - val_loss: 0.4543 - val_accuracy: 0.7901
# Epoch 46/120
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4847 - accuracy: 0.7926 - val_loss: 0.3860 - val_accuracy: 0.8519
# Epoch 47/120
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5070 - accuracy: 0.7766 - val_loss: 0.4813 - val_accuracy: 0.7654
# Epoch 48/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4829 - accuracy: 0.7926 - val_loss: 0.7997 - val_accuracy: 0.6420
# Epoch 49/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6450 - accuracy: 0.7287 - val_loss: 0.6204 - val_accuracy: 0.6914
# Epoch 50/120
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5508 - accuracy: 0.7553 - val_loss: 0.3910 - val_accuracy: 0.7901
# Epoch 51/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4721 - accuracy: 0.7713 - val_loss: 0.3923 - val_accuracy: 0.7901
# Epoch 52/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4434 - accuracy: 0.7872 - val_loss: 0.4006 - val_accuracy: 0.8025
# Epoch 53/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4719 - accuracy: 0.8032 - val_loss: 0.3935 - val_accuracy: 0.7901
# Epoch 54/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4547 - accuracy: 0.7819 - val_loss: 0.4150 - val_accuracy: 0.7901
# Epoch 55/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4594 - accuracy: 0.8032 - val_loss: 0.3812 - val_accuracy: 0.8272
# Epoch 56/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5065 - accuracy: 0.7713 - val_loss: 0.4012 - val_accuracy: 0.8025
# Epoch 57/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4506 - accuracy: 0.8138 - val_loss: 0.3707 - val_accuracy: 0.8765
# Epoch 58/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4873 - accuracy: 0.7926 - val_loss: 0.3696 - val_accuracy: 0.8642
# Epoch 59/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4815 - accuracy: 0.8032 - val_loss: 0.3744 - val_accuracy: 0.8642
# Epoch 60/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5145 - accuracy: 0.7394 - val_loss: 0.4447 - val_accuracy: 0.7901
# Epoch 61/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4600 - accuracy: 0.8245 - val_loss: 0.3632 - val_accuracy: 0.8642
# Epoch 62/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4347 - accuracy: 0.8032 - val_loss: 0.3734 - val_accuracy: 0.8272
# Epoch 63/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4417 - accuracy: 0.8245 - val_loss: 0.4203 - val_accuracy: 0.7901
# Epoch 64/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4415 - accuracy: 0.7979 - val_loss: 0.3639 - val_accuracy: 0.8642
# Epoch 65/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4141 - accuracy: 0.8298 - val_loss: 0.4345 - val_accuracy: 0.7901
# Epoch 66/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4353 - accuracy: 0.7926 - val_loss: 0.3687 - val_accuracy: 0.8642
# Epoch 67/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4426 - accuracy: 0.8191 - val_loss: 0.4123 - val_accuracy: 0.7901
# Epoch 68/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4369 - accuracy: 0.8138 - val_loss: 0.3725 - val_accuracy: 0.8519
# Epoch 69/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4022 - accuracy: 0.8245 - val_loss: 0.4042 - val_accuracy: 0.8025
# Epoch 70/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4667 - accuracy: 0.7819 - val_loss: 0.4655 - val_accuracy: 0.7778
# Epoch 71/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4475 - accuracy: 0.8191 - val_loss: 0.3596 - val_accuracy: 0.8395
# Epoch 72/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4459 - accuracy: 0.7979 - val_loss: 0.3630 - val_accuracy: 0.8395
# Epoch 73/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3912 - accuracy: 0.8457 - val_loss: 0.3808 - val_accuracy: 0.8148
# Epoch 74/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4117 - accuracy: 0.8351 - val_loss: 0.3602 - val_accuracy: 0.8519
# Epoch 75/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4778 - accuracy: 0.8085 - val_loss: 0.4232 - val_accuracy: 0.7901
# Epoch 76/120
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3987 - accuracy: 0.8404 - val_loss: 0.3790 - val_accuracy: 0.8519
# Epoch 77/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4078 - accuracy: 0.8298 - val_loss: 0.4365 - val_accuracy: 0.7901
# Epoch 78/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4133 - accuracy: 0.8191 - val_loss: 0.3570 - val_accuracy: 0.8519
# Epoch 79/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4160 - accuracy: 0.8138 - val_loss: 0.3562 - val_accuracy: 0.8519
# Epoch 80/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4053 - accuracy: 0.8245 - val_loss: 0.4367 - val_accuracy: 0.7901
# Epoch 81/120
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4465 - accuracy: 0.7766 - val_loss: 0.4199 - val_accuracy: 0.7901
# Epoch 82/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4333 - accuracy: 0.8085 - val_loss: 0.3754 - val_accuracy: 0.8642
# Epoch 83/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4014 - accuracy: 0.8351 - val_loss: 0.3640 - val_accuracy: 0.8395
# Epoch 84/120
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4092 - accuracy: 0.8404 - val_loss: 0.3668 - val_accuracy: 0.8395
# Epoch 85/120
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4524 - accuracy: 0.7872 - val_loss: 0.3677 - val_accuracy: 0.8395
# Epoch 86/120
# 24/24 [==============================] - 0s 7ms/step - loss: 0.3852 - accuracy: 0.8564 - val_loss: 0.3592 - val_accuracy: 0.8395
# Epoch 87/120
# 24/24 [==============================] - 0s 8ms/step - loss: 0.4187 - accuracy: 0.8245 - val_loss: 0.3624 - val_accuracy: 0.8395
# Epoch 88/120
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3984 - accuracy: 0.8564 - val_loss: 0.3528 - val_accuracy: 0.8519
# Epoch 89/120
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3891 - accuracy: 0.8511 - val_loss: 0.5116 - val_accuracy: 0.7407
# Epoch 90/120
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5013 - accuracy: 0.7660 - val_loss: 0.4949 - val_accuracy: 0.7778
# Epoch 91/120
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4292 - accuracy: 0.8191 - val_loss: 0.3578 - val_accuracy: 0.8519
# Epoch 92/120
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4067 - accuracy: 0.8245 - val_loss: 0.3759 - val_accuracy: 0.8272
# Epoch 93/120
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4430 - accuracy: 0.8085 - val_loss: 0.4121 - val_accuracy: 0.7901
# Epoch 94/120
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4043 - accuracy: 0.8298 - val_loss: 0.3653 - val_accuracy: 0.8272
# Epoch 95/120
# 24/24 [==============================] - 0s 7ms/step - loss: 0.3970 - accuracy: 0.8617 - val_loss: 0.3504 - val_accuracy: 0.8642
# Epoch 96/120
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3928 - accuracy: 0.8511 - val_loss: 0.3676 - val_accuracy: 0.8272
# Epoch 97/120
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4487 - accuracy: 0.8138 - val_loss: 0.3457 - val_accuracy: 0.8519
# Epoch 98/120
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4600 - accuracy: 0.8032 - val_loss: 0.4341 - val_accuracy: 0.7901
# Epoch 99/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4311 - accuracy: 0.7872 - val_loss: 0.3765 - val_accuracy: 0.8519
# Epoch 100/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4238 - accuracy: 0.8245 - val_loss: 0.5435 - val_accuracy: 0.7160
# Epoch 101/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4392 - accuracy: 0.7872 - val_loss: 0.4355 - val_accuracy: 0.7901
# Epoch 102/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4005 - accuracy: 0.8457 - val_loss: 0.4023 - val_accuracy: 0.8148
# Epoch 103/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4085 - accuracy: 0.8032 - val_loss: 0.4258 - val_accuracy: 0.7901
# Epoch 104/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4335 - accuracy: 0.8085 - val_loss: 0.3698 - val_accuracy: 0.8272
# Epoch 105/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4121 - accuracy: 0.8138 - val_loss: 0.3539 - val_accuracy: 0.9012
# Epoch 106/120
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3760 - accuracy: 0.8457 - val_loss: 0.4467 - val_accuracy: 0.7901
# Epoch 107/120
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5097 - accuracy: 0.7713 - val_loss: 0.3854 - val_accuracy: 0.8642
# Epoch 108/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3925 - accuracy: 0.8457 - val_loss: 0.4029 - val_accuracy: 0.8519
# Epoch 109/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4397 - accuracy: 0.8191 - val_loss: 0.3644 - val_accuracy: 0.8272
# Epoch 110/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4323 - accuracy: 0.7872 - val_loss: 0.3625 - val_accuracy: 0.8272
# Epoch 111/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3989 - accuracy: 0.8245 - val_loss: 0.3589 - val_accuracy: 0.8889
# Epoch 112/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4284 - accuracy: 0.8085 - val_loss: 0.4190 - val_accuracy: 0.7901
# Epoch 113/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4778 - accuracy: 0.8085 - val_loss: 0.4759 - val_accuracy: 0.7778
# Epoch 114/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5668 - accuracy: 0.7021 - val_loss: 0.4384 - val_accuracy: 0.7901
# Epoch 115/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4456 - accuracy: 0.8085 - val_loss: 0.3484 - val_accuracy: 0.8519
# Epoch 116/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4448 - accuracy: 0.8191 - val_loss: 0.3573 - val_accuracy: 0.8519
# Epoch 117/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4104 - accuracy: 0.8457 - val_loss: 0.4220 - val_accuracy: 0.7901
# Epoch 118/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3742 - accuracy: 0.8298 - val_loss: 0.3485 - val_accuracy: 0.8519
# Epoch 119/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4030 - accuracy: 0.8351 - val_loss: 0.4098 - val_accuracy: 0.8272
# Epoch 120/120
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4354 - accuracy: 0.8351 - val_loss: 0.3632 - val_accuracy: 0.8395

# %%
# evaluate the model
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.3727 - accuracy: 0.8439
# accuracy: 84.39%

# %%
# Visualize training history

# list all data in history
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for accuracy
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
