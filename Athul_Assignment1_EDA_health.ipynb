# %% [markdown]
# <a href="https://colab.research.google.com/github/ATHULTC/first-project/blob/main/Athul_Assignment1_EDA_health.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/healthexp.csv')

# %%
df
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
df.dtypes
# Out:
# Year                 int64
# Country             object
# Spending_USD       float64
# Life_Expectancy    float64
# dtype: object

# %%
df.size
# Out:
# 1096

# %%
df.shape
# Out:
# (274, 4)

# %%
df.values
# Out:
# array([[1970, 'Germany', 252.311, 70.6],
#        [1970, 'France', 192.143, 72.2],
#        [1970, 'Great Britain', 123.993, 71.9],
#        ...,
#        [2020, 'Great Britain', 5018.7, 80.4],
#        [2020, 'Japan', 4665.641, 84.7],
#        [2020, 'USA', 11859.179, 77.0]], dtype=object)

# %%
df.describe()
# Out:
#               Year  Spending_USD  Life_Expectancy
# count   274.000000    274.000000       274.000000
# mean   1996.992701   2789.338905        77.909489
# std      14.180933   2194.939785         3.276263
# min    1970.000000    123.993000        70.600000
# 25%    1985.250000   1038.357000        75.525000
# 50%    1998.000000   2295.578000        78.100000
# 75%    2009.000000   4055.610000        80.575000
# max    2020.000000  11859.179000        84.700000

# %%
df.max()
# Out:
# Year                    2020
# Country                  USA
# Spending_USD       11859.179
# Life_Expectancy         84.7
# dtype: object

# %%
df.min()
# Out:
# Year                  1970
# Country             Canada
# Spending_USD       123.993
# Life_Expectancy       70.6
# dtype: object

# %%
df.mean()
# Out:
# <ipython-input-12-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Year               1996.992701
# Spending_USD       2789.338905
# Life_Expectancy      77.909489
# dtype: float64

# %%
df.median()
# Out:
# <ipython-input-13-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Year               1998.000
# Spending_USD       2295.578
# Life_Expectancy      78.100
# dtype: float64

# %%
df.std()
# Out:
# <ipython-input-14-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Year                 14.180933
# Spending_USD       2194.939785
# Life_Expectancy       3.276263
# dtype: float64

# %%
df.dropna()
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
df.Life_Expectancy
# Out:
# 0      70.6
# 1      72.2
# 2      71.9
# 3      72.0
# 4      70.9
#        ...
# 269    81.1
# 270    82.3
# 271    80.4
# 272    84.7
# 273    77.0
# Name: Life_Expectancy, Length: 274, dtype: float64

# %%
df_Life= df.groupby(['Life_Expectancy'])

# %%
df_Life

# %%
df_Life.mean()
# Out:
# <ipython-input-19-757177fc2e16>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_Life.mean()
#                    Year  Spending_USD
# Life_Expectancy
# 70.6             1970.0      252.3110
# 70.8             1971.0      298.2510
# 70.9             1970.0      326.9610
# 71.0             1972.0      337.3640
# 71.2             1971.5      377.5425
# ...                 ...           ...
# 84.1             2016.0     4295.8580
# 84.2             2017.0     4412.8520
# 84.3             2018.0     4554.2760
# 84.4             2019.0     4610.7940
# 84.7             2020.0     4665.6410
#
# [118 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# ...
